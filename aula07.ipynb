# %% [markdown]
# <a href="https://colab.research.google.com/github/Kauan-Santos-Souza-Dev/Engenharia_de_Prompt/blob/main/aula07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 07 - MiniProjeto
#
# **nome: Kadjija Valéria**
#
# **Engenharia de Prompt**

# %% [markdown]
# # Antes - Ineficiente:

# %%
soma = 0
i=0
while i < len(numeros):
  soma += numeros[i]
  i=i+

# %% [markdown]
# # Depois - Eficiente:

# %%
numeros = [1, 2, 3, 4, 5] # Exemplo de definição da lista 'numeros'

# Usando um laço 'for' (mais legível e idiomático para iteração):
# soma = 0
# for numero in numeros:
#     soma += numero

# Usando a função 'sum()' (a forma mais eficiente e Pythonic):
soma = sum(numeros)
