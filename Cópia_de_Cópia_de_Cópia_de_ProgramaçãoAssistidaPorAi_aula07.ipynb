# %% [markdown]
# <a href="https://colab.research.google.com/github/Kauan-Santos-Souza-Dev/Engenharia_de_Prompt/blob/main/C%C3%B3pia_de_C%C3%B3pia_de_C%C3%B3pia_de_Programa%C3%A7%C3%A3oAssistidaPorAi_aula07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 07 - MiniProjeto
#
# **nome: Kadjija Valéria**
#
# **Engenharia de Prompt**

# %% [markdown]
# # Soma de Lista:

# %% [markdown]
# **Antes - Ineficiente:**

# %%
soma = 0
i = 0
while i < len(numeros):
  soma += numeros[i]
  i = i + 1

# %% [markdown]
# **Depois - Eficiente:**

# %%
numeros = [1, 2, 3, 4, 5]
#erro de sintaxe no laço while
# Forma refatorada e eficiente:
soma = sum(numeros)
print(f'A soma é: {soma}')
# Out:
# A soma é: 15

# %% [markdown]
# # Número Primo:

# %% [markdown]
# **Antes - Ineficiente:**

# %%
def eh_Primo(n):
  for i in range(2, n):
    if n % i == 0:
      return False
  return True

# %% [markdown]
# **Depois - Eficiente:**

# %%
import math

def eh_Primo(n):
  if n < 2:
    return False
  # Otimização: verificar apenas até a raiz quadrada de n
  for i in range(2, int(math.sqrt(n)) + 1):
    if n % i == 0:
      return False
  return True

# Teste
numero = 17
print(f'O número {numero} é primo? {eh_Primo(numero)}')
# Out:
# O número 17 é primo? True

# %% [markdown]
# #Inversão de String:

# %% [markdown]
# **Versão ineficiente:**

# %%
def invete_texto(texto):
  invertido = ''
  for letra in texto:
    invertido = letra + invertido
  return invertido

# %% [markdown]
# **Versão Eficiente**

# %%
def inverte_texto(texto):
  return texto[::-1]

# Teste
texto_original = 'Python'
print(f'Original: {texto_original}')
print(f'Invertido: {inverte_texto(texto_original)}')
# Out:
# Original: Python
# Invertido: nohtyP

# %% [markdown]
# # Desafio Guiado

# %% [markdown]
# ![Captura de tela_8-4-2026_221333_bb.cruzeirodosulvirtual.com.br.jpeg](data:image/jpeg;base64,...)

# %%
def soma(a, b):
  return a + b

def subtracao(a, b):
  return a - b

def multiplicacao(a, b):
  return a * b

def divisao(a, b):
  if b == 0:
    return "Erro: Divisão por zero!"
  return a / b

# Exemplo de uso:
num1 = 10
num2 = 5

print(f"Soma de {num1} e {num2}: {soma(num1, num2)}")
print(f"Subtração de {num1} e {num2}: {subtracao(num1, num2)}")
print(f"Multiplicação de {num1} e {num2}: {multiplicacao(num1, num2)}")
print(f"Divisão de {num1} e {num2}: {divisao(num1, num2)}")

# Exemplo com divisão por zero
num3 = 0
print(f"Divisão de {num1} e {num3}: {divisao(num1, num3)}")
